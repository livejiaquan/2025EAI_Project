# %% [markdown]
# # Knowledge Distillation
# - The concept of **knowledge distillation** is to utilize class probabilities of a higher-capacity model (teacher) as soft targets of a smaller model (student)
# - The implement processes can be divided into several stages:
#   1. Finish the `ResNet()` classes
#   2. Train the teacher model (ResNet50) and the student model (ResNet18) from scratch, i.e. **without KD**
#   3. Define the `Distiller()` class and `loss_re()`, `loss_fe()` functions
#   4. Train the student model **with KD** from the teacher model in two different ways, response-based and feature based distillation
#   5. Comparison of student models w/ & w/o KD

# %% [markdown]
# ## Setup

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /home/twccjq88/.local/lib/python3.9/site-packages (1.8.0)

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms, models
from torch.utils.data import DataLoader, Dataset, random_split
from torchinfo import summary
from tqdm import tqdm
import sys
import numpy as np
import math
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
torch.manual_seed(0)

# 設置設備：支援多 GPU
if torch.cuda.is_available():
    device = torch.device('cuda')
    # 檢查可用的 GPU 數量
    gpu_count = torch.cuda.device_count()
    print(f'使用 GPU 訓練，可用 GPU 數量: {gpu_count}')
    for i in range(gpu_count):
        print(f'  GPU {i}: {torch.cuda.get_device_name(i)}')
    use_multi_gpu = gpu_count > 1
else:
    device = torch.device('cpu')
    use_multi_gpu = False
    print('使用 CPU 訓練')

torch.backends.cudnn.benchmark = True
# Out:
# 使用 GPU 訓練，可用 GPU 數量: 2
#   GPU 0: Tesla V100-SXM2-32GB
#   GPU 1: Tesla V100-SXM2-32GB

# %% [markdown]
# ## Download dataset

# %%
validation_split = 0.2
batch_size = 128

# data augmentation and normalization
transform_train = transforms.Compose([
                    transforms.RandomCrop(32, padding=4),
                    transforms.RandomHorizontalFlip(),
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

transform_test = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# download dataset
train_and_val_dataset = torchvision.datasets.CIFAR10(
    root='dataset/',
    train=True,
    transform=transform_train,
    download=True
)

test_dataset = torchvision.datasets.CIFAR10(
    root='dataset/',
    train=False,
    transform=transform_test,
    download=True
)

# split train and validation dataset
train_size = int((1 - validation_split) * len(train_and_val_dataset))
val_size = len(train_and_val_dataset) - train_size
train_dataset, val_dataset = random_split(train_and_val_dataset, [train_size, val_size])

# create dataLoader
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

test_num = len(test_dataset)
test_steps = len(test_loader)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to dataset/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.9MB/s]
# Extracting dataset/cifar-10-python.tar.gz to dataset/
# Files already downloaded and verified

# %% [markdown]
# ## Create teacher and student models
# ### Define BottleNeck for ResNet50

# %%
class BottleNeck(nn.Module):
    expansion = 4

    def __init__(self, in_channel, out_channel, stride=1, downsample=None, **kwargs):
        super(BottleNeck, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel * self.expansion, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(out_channel * self.expansion)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = self.conv3(out)
        out = self.bn3(out)

        out += identity
        out = self.relu(out)

        return out

# %% [markdown]
# ### Define Resifual Block

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, stride=1, downsample=None, **kwargs):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.downsample = downsample

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out

# %% [markdown]
# ### Define ResNet Model

# %%
class ResNet(nn.Module):

    def __init__(self, block, blocks_num, num_classes=1000):
        super(ResNet, self).__init__()
        self.in_channel = 64

        self.conv1 = nn.Conv2d(3, self.in_channel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        self.layer1 = self._make_layer(block, 64, blocks_num[0])
        self.layer2 = self._make_layer(block, 128, blocks_num[1], stride=2)
        self.layer3 = self._make_layer(block, 256, blocks_num[2], stride=2)
        self.layer4 = self._make_layer(block, 512, blocks_num[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None
        if stride != 1 or self.in_channel != channel * block.expansion:
            downsample = nn.Sequential(
                nn.Conv2d(self.in_channel, channel * block.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(channel * block.expansion))

        layers = []
        layers.append(block(self.in_channel, channel, downsample=downsample, stride=stride))
        self.in_channel = channel * block.expansion

        for _ in range(1, block_num):
            layers.append(block(self.in_channel, channel))

        return nn.Sequential(*layers)

    def forward(self, x):
        # 1. Finish the forward pass and return the output layer as well as hidden features.
        # 2. The output layer and hidden features will be used later for distilling.
        # 3. You can refer to the ResNet structure illustration to finish it.

        # 初始卷積層
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        
        # 通過四個 ResNet 層，並保存每層的輸出作為特徵
        feature1 = self.layer1(x)
        feature2 = self.layer2(feature1)
        feature3 = self.layer3(feature2)
        feature4 = self.layer4(feature3)
        
        # 全局平均池化
        x = self.avgpool(feature4)
        # 展平為一維向量
        x = torch.flatten(x, 1)
        # 全連接層得到最終輸出
        x = self.fc(x)

        return x, [feature1, feature2, feature3, feature4]

# %% [markdown]
# ### Define ResNet50 and Resnet18

# %%
def resnet18(num_classes=10):
    return ResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def resnet50(num_classes=10):
    return ResNet(BottleNeck, [3, 4, 6, 3], num_classes=num_classes)

# %% [markdown]
# ## Teacher Model (ResNet50)

# %%
Teacher = resnet50(num_classes=10)  # commment out this line if loading trained teacher model
# Teacher = torch.load('Teacher.pt', weights_only=False)  # loading trained teacher model
Teacher = Teacher.to(device)

# 如果有多個 GPU，使用 DataParallel 進行並行訓練
if use_multi_gpu:
    Teacher = nn.DataParallel(Teacher)
    print(f'Teacher 模型使用 {torch.cuda.device_count()} 個 GPU 進行訓練')
# Out:
# Teacher 模型使用 2 個 GPU 進行訓練

# %%
summary(Teacher)
# Out:
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# DataParallel                                  --
# ├─ResNet: 1-1                                 --
# │    └─Conv2d: 2-1                            1,728
# │    └─BatchNorm2d: 2-2                       128
# │    └─ReLU: 2-3                              --
# │    └─MaxPool2d: 2-4                         --
# │    └─Sequential: 2-5                        --
# │    │    └─BottleNeck: 3-1                   75,008
# │    │    └─BottleNeck: 3-2                   70,400
# │    │    └─BottleNeck: 3-3                   70,400
# │    └─Sequential: 2-6                        --
# │    │    └─BottleNeck: 3-4                   379,392
# │    │    └─BottleNeck: 3-5                   280,064
# │    │    └─BottleNeck: 3-6                   280,064
# │    │    └─BottleNeck: 3-7                   280,064
# │    └─Sequential: 2-7                        --
# │    │    └─BottleNeck: 3-8                   1,512,448
# │    │    └─BottleNeck: 3-9                   1,117,184
# │    │    └─BottleNeck: 3-10                  1,117,184
# │    │    └─BottleNeck: 3-11                  1,117,184
# │    │    └─BottleNeck: 3-12                  1,117,184
# │    │    └─BottleNeck: 3-13                  1,117,184
# │    └─Sequential: 2-8                        --
# │    │    └─BottleNeck: 3-14                  6,039,552
# │    │    └─BottleNeck: 3-15                  4,462,592
# │    │    └─BottleNeck: 3-16                  4,462,592
# │    └─AdaptiveAvgPool2d: 2-9                 --
# │    └─Linear: 2-10                           20,490
# ======================================================================
# Total params: 23,520,842
# Trainable params: 23,520,842
# Non-trainable params: 0
# ======================================================================

# %% [markdown]
# ## Student Model (ResNet18)

# %%
Student = resnet18(num_classes=10)  # commment out this line if loading trained student model
# Student = torch.load('Student.pt', weights_only=False)  # loading trained student model
Student = Student.to(device)

# 如果有多個 GPU，使用 DataParallel 進行並行訓練
if use_multi_gpu:
    Student = nn.DataParallel(Student)
    print(f'Student 模型使用 {torch.cuda.device_count()} 個 GPU 進行訓練')
# Out:
# Student 模型使用 2 個 GPU 進行訓練

# %%
summary(Student)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─BasicBlock: 2-1                   --
# │    │    └─Conv2d: 3-1                  36,864
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─ReLU: 3-3                    --
# │    │    └─Conv2d: 3-4                  36,864
# │    │    └─BatchNorm2d: 3-5             128
# │    └─BasicBlock: 2-2                   --
# │    │    └─Conv2d: 3-6                  36,864
# │    │    └─BatchNorm2d: 3-7             128
# │    │    └─ReLU: 3-8                    --
# │    │    └─Conv2d: 3-9                  36,864
# │    │    └─BatchNorm2d: 3-10            128
# ├─Sequential: 1-6                        --
# │    └─BasicBlock: 2-3                   --
# │    │    └─Conv2d: 3-11                 73,728
# │    │    └─BatchNorm2d: 3-12            256
# │    │    └─ReLU: 3-13                   --
# │    │    └─Conv2d: 3-14                 147,456
# │    │    └─BatchNorm2d: 3-15            256
# │    │    └─Sequential: 3-16             8,448
# │    └─BasicBlock: 2-4                   --
# │    │    └─Conv2d: 3-17                 147,456
# │    │    └─BatchNorm2d: 3-18            256
# │    │    └─ReLU: 3-19                   --
# │    │    └─Conv2d: 3-20                 147,456
# │    │    └─BatchNorm2d: 3-21            256
# ├─Sequential: 1-7                        --
# │    └─BasicBlock: 2-5                   --
# │    │    └─Conv2d: 3-22                 294,912
# │    │    └─BatchNorm2d: 3-23            512
# │    │    └─ReLU: 3-24                   --
# │    │    └─Conv2d: 3-25                 589,824
# │    │    └─BatchNorm2d: 3-26            512
# │    │    └─Sequential: 3-27             33,280
# │    └─BasicBlock: 2-6                   --
# │    │    └─Conv2d: 3-28                 589,824
# │    │    └─BatchNorm2d: 3-29            512
# │    │    └─ReLU: 3-30                   --
# │    │    └─Conv2d: 3-31                 589,824
# │    │    └─BatchNorm2d: 3-32            512
# ├─Sequential: 1-8                        --
# │    └─BasicBlock: 2-7                   --
# │    │    └─Conv2d: 3-33                 1,179,648
# │    │    └─BatchNorm2d: 3-34            1,024
# │    │    └─ReLU: 3-35                   --
# │    │    └─Conv2d: 3-36                 2,359,296
# │    │    └─BatchNorm2d: 3-37            1,024
# │    │    └─Sequential: 3-38             132,096
# │    └─BasicBlock: 2-8                   --
# │    │    └─Conv2d: 3-39                 2,359,296
# │    │    └─BatchNorm2d: 3-40            1,024
# │    │    └─ReLU: 3-41                   --
# │    │    └─Conv2d: 3-42                 2,359,296
# │    │    └─BatchNorm2d: 3-43            1,024
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           5,130
# =================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Define training function

# %%
def train_from_scratch(model, train_loader, val_loader, epochs, learning_rate, device, model_name):
    criterion = nn.CrossEntropyLoss()
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(params, lr=learning_rate)

    loss = []
    train_error=[]
    val_error = []
    valdation_error = []
    train_loss = []
    valdation_loss = []
    train_accuraacy = []
    valdation_accuracy= []

    for epoch in range(epochs):
        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc = 0.0
        correct = 0.
        total = 0.
        V_correct = 0.
        V_total = 0.

        model.train()
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            logits, hidden = model(images)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * images.size(0)
            pred = logits.data.max(1, keepdim=True)[1]
            correct += np.sum(np.squeeze(pred.eq(labels.data.view_as(pred))).cpu().numpy())
            total += images.size(0)
            train_acc =  correct/total
            train_bar.desc = "train epoch[{}/{}]".format(epoch + 1, epochs)

        model.eval()
        with torch.no_grad():
            val_bar = tqdm(val_loader, file=sys.stdout)
            for val_data in val_bar:
                val_images, val_labels = val_data
                val_images, val_labels = val_images.to(device), val_labels.to(device)
                outputs, hidden_outputs = model(val_images)
                loss = criterion(outputs, val_labels)
                valid_loss += loss.item() * val_images.size(0)
                pred = outputs.data.max(1, keepdim=True)[1]
                V_correct += np.sum(np.squeeze(pred.eq(val_labels.data.view_as(pred))).cpu().numpy())
                V_total += val_images.size(0)
                val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)

        train_loss = train_loss / len(train_loader.dataset)
        train_error.append(train_loss)
        valid_loss = valid_loss / len(val_loader.dataset)
        val_error.append(valid_loss)
        train_accuraacy.append( correct / total)
        valdation_accuracy.append(V_correct / V_total)

        print('\tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(train_loss, valid_loss))
        print('\tTrain Accuracy: %.3fd%% (%2d/%2d)\tValdation Accuracy: %.3fd%% (%2d/%2d) '% (100. * correct / total, correct, total, 100. * V_correct / V_total, V_correct, V_total))

    torch.save(model, f'{model_name}.pt')
    print(f'{model_name}.pt is saved')

    print('Finished Training')

# %% [markdown]
# ## Define testing function

# %%
def test(model, test_loader ,device, type=None):
    criterion = nn.CrossEntropyLoss()
    acc = 0.0
    test_loss = 0.0

    if type == None:
        model.eval()
    elif type == 'distiller':
        model.eval()
        model.teacher.eval()
        model.student.eval()
    else:
       raise ValueError(f'Error: only support response-based and feature-based distillation')

    with torch.no_grad():
        test_bar = tqdm(test_loader, file=sys.stdout)
        for test_data in test_bar:
            test_images, test_labels = test_data
            test_images, test_labels = test_images.to(device), test_labels.to(device)
            if type == None:
                outputs, features = model(test_images)
                loss = criterion(outputs, test_labels)
            elif type == 'distiller':
                outputs, loss = model(test_images, test_labels)
            else:
                raise ValueError(f'Error: only support response-based and feature-based distillation')

            predict_y = torch.max(outputs, dim=1)[1]
            acc += torch.eq(predict_y, test_labels.to(device)).sum().item()
            test_loss += loss.item()
            test_bar.desc = "test"

    test_accurate = acc / test_num
    print('test_loss: %.3f  test_accuracy: %.3f' %(test_loss / test_steps, test_accurate * 100))
    return test_loss / test_steps, test_accurate * 100.

# %% [markdown]
# ## Train Teacher and Student model from scratch

# %%
# Decide the epochs and learning rate
train_from_scratch(Teacher, train_loader, val_loader, epochs=50, learning_rate=0.001, device=device, model_name="Teacher")
# Out:
# train epoch[1/50]: 100%|██████████| 313/313 [02:11<00:00,  2.38it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.744452 	Validation Loss: 0.881200
# 	Train Accuracy: 74.222d% (29689/40000)	Valdation Accuracy: 70.990d% (7099/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.615066 	Validation Loss: 0.769146
# 	Train Accuracy: 78.755d% (31502/40000)	Valdation Accuracy: 75.020d% (7502/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:28<00:00,  2.73it/s]
# 	Training Loss: 0.542589 	Validation Loss: 0.582035
# 	Train Accuracy: 81.448d% (32579/40000)	Valdation Accuracy: 80.380d% (8038/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:28<00:00,  2.73it/s]
# 	Training Loss: 0.487883 	Validation Loss: 0.570289
# 	Train Accuracy: 83.312d% (33325/40000)	Valdation Accuracy: 80.510d% (8051/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [02:11<00:00,  2.38it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.446980 	Validation Loss: 0.514792
# 	Train Accuracy: 84.715d% (33886/40000)	Valdation Accuracy: 82.740d% (8274/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:29<00:00,  2.70it/s]
# 	Training Loss: 0.407742 	Validation Loss: 0.497107
# 	Train Accuracy: 86.020d% (34408/40000)	Valdation Accuracy: 83.430d% (8343/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.376248 	Validation Loss: 0.501206
# 	Train Accuracy: 87.060d% (34824/40000)	Valdation Accuracy: 83.050d% (8305/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.353037 	Validation Loss: 0.500681
# 	Train Accuracy: 87.858d% (35143/40000)	Valdation Accuracy: 83.300d% (8330/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.323227 	Validation Loss: 0.479723
# 	Train Accuracy: 88.748d% (35499/40000)	Valdation Accuracy: 84.250d% (8425/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.306888 	Validation Loss: 0.422121
# 	Train Accuracy: 89.263d% (35705/40000)	Valdation Accuracy: 85.970d% (8597/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.276226 	Validation Loss: 0.442992
# 	Train Accuracy: 90.475d% (36190/40000)	Valdation Accuracy: 85.420d% (8542/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.269505 	Validation Loss: 0.432431
# 	Train Accuracy: 90.543d% (36217/40000)	Valdation Accuracy: 85.930d% (8593/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [02:11<00:00,  2.37it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:28<00:00,  2.73it/s]
# 	Training Loss: 0.254241 	Validation Loss: 0.369130
# 	Train Accuracy: 91.225d% (36490/40000)	Valdation Accuracy: 88.060d% (8806/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.245208 	Validation Loss: 0.409527
# 	Train Accuracy: 91.448d% (36579/40000)	Valdation Accuracy: 87.070d% (8707/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [02:11<00:00,  2.38it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.227872 	Validation Loss: 0.352743
# 	Train Accuracy: 92.032d% (36813/40000)	Valdation Accuracy: 88.270d% (8827/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [02:11<00:00,  2.38it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.204672 	Validation Loss: 0.376983
# 	Train Accuracy: 92.868d% (37147/40000)	Valdation Accuracy: 87.530d% (8753/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.198558 	Validation Loss: 0.359935
# 	Train Accuracy: 93.055d% (37222/40000)	Valdation Accuracy: 88.710d% (8871/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.188981 	Validation Loss: 0.403249
# 	Train Accuracy: 93.270d% (37308/40000)	Valdation Accuracy: 87.380d% (8738/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.175211 	Validation Loss: 0.353078
# 	Train Accuracy: 93.765d% (37506/40000)	Valdation Accuracy: 88.480d% (8848/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.166335 	Validation Loss: 0.357874
# 	Train Accuracy: 94.147d% (37659/40000)	Valdation Accuracy: 88.760d% (8876/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.161024 	Validation Loss: 0.367249
# 	Train Accuracy: 94.287d% (37715/40000)	Valdation Accuracy: 88.970d% (8897/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [02:11<00:00,  2.38it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.148079 	Validation Loss: 0.379008
# 	Train Accuracy: 94.797d% (37919/40000)	Valdation Accuracy: 88.980d% (8898/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.149519 	Validation Loss: 0.405265
# 	Train Accuracy: 94.735d% (37894/40000)	Valdation Accuracy: 88.010d% (8801/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.135461 	Validation Loss: 0.329400
# 	Train Accuracy: 95.110d% (38044/40000)	Valdation Accuracy: 90.120d% (9012/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.126869 	Validation Loss: 0.399157
# 	Train Accuracy: 95.543d% (38217/40000)	Valdation Accuracy: 88.740d% (8874/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.121736 	Validation Loss: 0.383880
# 	Train Accuracy: 95.760d% (38304/40000)	Valdation Accuracy: 88.690d% (8869/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.120427 	Validation Loss: 0.355484
# 	Train Accuracy: 95.835d% (38334/40000)	Valdation Accuracy: 89.770d% (8977/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.114887 	Validation Loss: 0.368586
# 	Train Accuracy: 96.070d% (38428/40000)	Valdation Accuracy: 89.190d% (8919/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.103301 	Validation Loss: 0.359960
# 	Train Accuracy: 96.320d% (38528/40000)	Valdation Accuracy: 90.190d% (9019/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.109087 	Validation Loss: 0.360845
# 	Train Accuracy: 96.213d% (38485/40000)	Valdation Accuracy: 89.630d% (8963/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.098658 	Validation Loss: 0.378849
# 	Train Accuracy: 96.403d% (38561/40000)	Valdation Accuracy: 89.520d% (8952/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.089190 	Validation Loss: 0.347318
# 	Train Accuracy: 96.858d% (38743/40000)	Valdation Accuracy: 90.430d% (9043/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.095108 	Validation Loss: 0.346541
# 	Train Accuracy: 96.680d% (38672/40000)	Valdation Accuracy: 89.820d% (8982/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.084782 	Validation Loss: 0.377971
# 	Train Accuracy: 97.093d% (38837/40000)	Valdation Accuracy: 89.990d% (8999/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.085798 	Validation Loss: 0.344329
# 	Train Accuracy: 97.043d% (38817/40000)	Valdation Accuracy: 90.300d% (9030/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.083833 	Validation Loss: 0.353292
# 	Train Accuracy: 97.105d% (38842/40000)	Valdation Accuracy: 90.570d% (9057/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.073202 	Validation Loss: 0.381930
# 	Train Accuracy: 97.400d% (38960/40000)	Valdation Accuracy: 89.930d% (8993/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [02:11<00:00,  2.38it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:28<00:00,  2.73it/s]
# 	Training Loss: 0.077927 	Validation Loss: 0.343697
# 	Train Accuracy: 97.267d% (38907/40000)	Valdation Accuracy: 90.850d% (9085/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.072629 	Validation Loss: 0.370987
# 	Train Accuracy: 97.418d% (38967/40000)	Valdation Accuracy: 90.480d% (9048/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.069931 	Validation Loss: 0.387833
# 	Train Accuracy: 97.535d% (39014/40000)	Valdation Accuracy: 90.150d% (9015/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# 	Training Loss: 0.070781 	Validation Loss: 0.394566
# 	Train Accuracy: 97.515d% (39006/40000)	Valdation Accuracy: 89.740d% (8974/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:28<00:00,  2.73it/s]
# 	Training Loss: 0.069648 	Validation Loss: 0.380746
# 	Train Accuracy: 97.545d% (39018/40000)	Valdation Accuracy: 90.370d% (9037/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [02:11<00:00,  2.39it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.058314 	Validation Loss: 0.391552
# 	Train Accuracy: 97.935d% (39174/40000)	Valdation Accuracy: 90.270d% (9027/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:29<00:00,  2.70it/s]
# 	Training Loss: 0.064004 	Validation Loss: 0.367190
# 	Train Accuracy: 97.760d% (39104/40000)	Valdation Accuracy: 90.410d% (9041/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [02:10<00:00,  2.40it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:28<00:00,  2.73it/s]
# 	Training Loss: 0.076881 	Validation Loss: 0.368633
# 	Train Accuracy: 97.345d% (38938/40000)	Valdation Accuracy: 90.540d% (9054/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.058582 	Validation Loss: 0.368190
# 	Train Accuracy: 97.922d% (39169/40000)	Valdation Accuracy: 90.540d% (9054/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.058627 	Validation Loss: 0.416278
# 	Train Accuracy: 97.960d% (39184/40000)	Valdation Accuracy: 89.520d% (8952/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [02:10<00:00,  2.40it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.060208 	Validation Loss: 0.394634
# 	Train Accuracy: 97.905d% (39162/40000)	Valdation Accuracy: 90.450d% (9045/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [02:10<00:00,  2.39it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:29<00:00,  2.70it/s]
# 	Training Loss: 0.053041 	Validation Loss: 0.375624
# 	Train Accuracy: 98.157d% (39263/40000)	Valdation Accuracy: 91.010d% (9101/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [02:10<00:00,  2.40it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:29<00:00,  2.71it/s]
# 	Training Loss: 0.046078 	Validation Loss: 0.381505
# 	Train Accuracy: 98.412d% (39365/40000)	Valdation Accuracy: 91.020d% (9102/10000)
# Teacher.pt is saved
# Finished Training

# %%
T_loss, T_accuracy = test(Teacher, test_loader, device=device)
# Out:
# test: 100%|██████████| 79/79 [00:29<00:00,  2.72it/s]
# test_loss: 0.433  test_accuracy: 90.900

# %%
# Decide the epochs and learning rate
train_from_scratch(Student, train_loader, val_loader, epochs= 50, learning_rate= 0.001, device=device, model_name="Student")
# Out:
# train epoch[1/50]: 100%|██████████| 313/313 [00:54<00:00,  5.72it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:12<00:00,  6.52it/s]
# 	Training Loss: 1.294300 	Validation Loss: 1.203104
# 	Train Accuracy: 53.032d% (21213/40000)	Valdation Accuracy: 56.790d% (5679/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.935933 	Validation Loss: 0.889185
# 	Train Accuracy: 66.418d% (26567/40000)	Valdation Accuracy: 68.800d% (6880/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [00:54<00:00,  5.74it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.748574 	Validation Loss: 0.727477
# 	Train Accuracy: 73.770d% (29508/40000)	Valdation Accuracy: 74.540d% (7454/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:12<00:00,  6.49it/s]
# 	Training Loss: 0.630760 	Validation Loss: 0.694219
# 	Train Accuracy: 78.100d% (31240/40000)	Valdation Accuracy: 75.320d% (7532/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:12<00:00,  6.48it/s]
# 	Training Loss: 0.556161 	Validation Loss: 0.568491
# 	Train Accuracy: 80.415d% (32166/40000)	Valdation Accuracy: 80.390d% (8039/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.493578 	Validation Loss: 0.519169
# 	Train Accuracy: 83.070d% (33228/40000)	Valdation Accuracy: 82.450d% (8245/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.442531 	Validation Loss: 0.480063
# 	Train Accuracy: 84.647d% (33859/40000)	Valdation Accuracy: 83.640d% (8364/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.407998 	Validation Loss: 0.570447
# 	Train Accuracy: 85.830d% (34332/40000)	Valdation Accuracy: 80.300d% (8030/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:12<00:00,  6.55it/s]
# 	Training Loss: 0.378056 	Validation Loss: 0.471471
# 	Train Accuracy: 86.935d% (34774/40000)	Valdation Accuracy: 84.060d% (8406/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:12<00:00,  6.57it/s]
# 	Training Loss: 0.342582 	Validation Loss: 0.505663
# 	Train Accuracy: 88.010d% (35204/40000)	Valdation Accuracy: 83.600d% (8360/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:12<00:00,  6.47it/s]
# 	Training Loss: 0.314633 	Validation Loss: 0.443656
# 	Train Accuracy: 89.040d% (35616/40000)	Valdation Accuracy: 85.210d% (8521/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:12<00:00,  6.52it/s]
# 	Training Loss: 0.295664 	Validation Loss: 0.431523
# 	Train Accuracy: 89.692d% (35877/40000)	Valdation Accuracy: 85.930d% (8593/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:12<00:00,  6.58it/s]
# 	Training Loss: 0.278148 	Validation Loss: 0.395952
# 	Train Accuracy: 90.435d% (36174/40000)	Valdation Accuracy: 86.470d% (8647/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [00:54<00:00,  5.74it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:12<00:00,  6.51it/s]
# 	Training Loss: 0.257732 	Validation Loss: 0.402795
# 	Train Accuracy: 91.037d% (36415/40000)	Valdation Accuracy: 86.920d% (8692/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.241598 	Validation Loss: 0.507528
# 	Train Accuracy: 91.630d% (36652/40000)	Valdation Accuracy: 83.920d% (8392/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:12<00:00,  6.54it/s]
# 	Training Loss: 0.231729 	Validation Loss: 0.388283
# 	Train Accuracy: 91.912d% (36765/40000)	Valdation Accuracy: 87.410d% (8741/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:12<00:00,  6.54it/s]
# 	Training Loss: 0.207472 	Validation Loss: 0.393065
# 	Train Accuracy: 92.763d% (37105/40000)	Valdation Accuracy: 87.550d% (8755/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:12<00:00,  6.56it/s]
# 	Training Loss: 0.197703 	Validation Loss: 0.424689
# 	Train Accuracy: 93.032d% (37213/40000)	Valdation Accuracy: 87.100d% (8710/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.182141 	Validation Loss: 0.373521
# 	Train Accuracy: 93.567d% (37427/40000)	Valdation Accuracy: 88.070d% (8807/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:12<00:00,  6.52it/s]
# 	Training Loss: 0.176862 	Validation Loss: 0.387986
# 	Train Accuracy: 93.868d% (37547/40000)	Valdation Accuracy: 87.820d% (8782/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:12<00:00,  6.51it/s]
# 	Training Loss: 0.160961 	Validation Loss: 0.351585
# 	Train Accuracy: 94.403d% (37761/40000)	Valdation Accuracy: 89.050d% (8905/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:12<00:00,  6.51it/s]
# 	Training Loss: 0.150907 	Validation Loss: 0.371717
# 	Train Accuracy: 94.703d% (37881/40000)	Valdation Accuracy: 88.590d% (8859/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:12<00:00,  6.45it/s]
# 	Training Loss: 0.140720 	Validation Loss: 0.407568
# 	Train Accuracy: 94.998d% (37999/40000)	Valdation Accuracy: 88.170d% (8817/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:12<00:00,  6.49it/s]
# 	Training Loss: 0.140402 	Validation Loss: 0.409657
# 	Train Accuracy: 95.138d% (38055/40000)	Valdation Accuracy: 87.630d% (8763/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [00:54<00:00,  5.74it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:12<00:00,  6.39it/s]
# 	Training Loss: 0.126037 	Validation Loss: 0.378369
# 	Train Accuracy: 95.495d% (38198/40000)	Valdation Accuracy: 88.970d% (8897/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:12<00:00,  6.57it/s]
# 	Training Loss: 0.113644 	Validation Loss: 0.354629
# 	Train Accuracy: 95.920d% (38368/40000)	Valdation Accuracy: 89.500d% (8950/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:12<00:00,  6.57it/s]
# 	Training Loss: 0.112661 	Validation Loss: 0.386578
# 	Train Accuracy: 96.043d% (38417/40000)	Valdation Accuracy: 88.910d% (8891/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:12<00:00,  6.56it/s]
# 	Training Loss: 0.112802 	Validation Loss: 0.395468
# 	Train Accuracy: 95.950d% (38380/40000)	Valdation Accuracy: 88.440d% (8844/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:12<00:00,  6.54it/s]
# 	Training Loss: 0.101650 	Validation Loss: 0.391794
# 	Train Accuracy: 96.412d% (38565/40000)	Valdation Accuracy: 89.270d% (8927/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [00:54<00:00,  5.74it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:12<00:00,  6.54it/s]
# 	Training Loss: 0.098407 	Validation Loss: 0.395502
# 	Train Accuracy: 96.537d% (38615/40000)	Valdation Accuracy: 88.810d% (8881/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [00:54<00:00,  5.74it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.091135 	Validation Loss: 0.376877
# 	Train Accuracy: 96.823d% (38729/40000)	Valdation Accuracy: 89.840d% (8984/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:12<00:00,  6.51it/s]
# 	Training Loss: 0.081866 	Validation Loss: 0.423612
# 	Train Accuracy: 97.085d% (38834/40000)	Valdation Accuracy: 88.730d% (8873/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:12<00:00,  6.48it/s]
# 	Training Loss: 0.085232 	Validation Loss: 0.426276
# 	Train Accuracy: 97.065d% (38826/40000)	Valdation Accuracy: 89.250d% (8925/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:12<00:00,  6.55it/s]
# 	Training Loss: 0.081436 	Validation Loss: 0.400826
# 	Train Accuracy: 97.165d% (38866/40000)	Valdation Accuracy: 88.980d% (8898/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:11<00:00,  6.59it/s]
# 	Training Loss: 0.077161 	Validation Loss: 0.398324
# 	Train Accuracy: 97.350d% (38940/40000)	Valdation Accuracy: 89.220d% (8922/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.074734 	Validation Loss: 0.378233
# 	Train Accuracy: 97.345d% (38938/40000)	Valdation Accuracy: 90.300d% (9030/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [00:54<00:00,  5.73it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:12<00:00,  6.52it/s]
# 	Training Loss: 0.069825 	Validation Loss: 0.432799
# 	Train Accuracy: 97.578d% (39031/40000)	Valdation Accuracy: 89.350d% (8935/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.068105 	Validation Loss: 0.397205
# 	Train Accuracy: 97.582d% (39033/40000)	Valdation Accuracy: 90.020d% (9002/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:12<00:00,  6.57it/s]
# 	Training Loss: 0.062143 	Validation Loss: 0.415118
# 	Train Accuracy: 97.835d% (39134/40000)	Valdation Accuracy: 89.560d% (8956/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:12<00:00,  6.52it/s]
# 	Training Loss: 0.059515 	Validation Loss: 0.416448
# 	Train Accuracy: 97.903d% (39161/40000)	Valdation Accuracy: 89.990d% (8999/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.063854 	Validation Loss: 0.391047
# 	Train Accuracy: 97.800d% (39120/40000)	Valdation Accuracy: 89.780d% (8978/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [00:54<00:00,  5.73it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.059965 	Validation Loss: 0.378904
# 	Train Accuracy: 97.815d% (39126/40000)	Valdation Accuracy: 90.320d% (9032/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:12<00:00,  6.50it/s]
# 	Training Loss: 0.056321 	Validation Loss: 0.447081
# 	Train Accuracy: 98.000d% (39200/40000)	Valdation Accuracy: 89.110d% (8911/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:12<00:00,  6.48it/s]
# 	Training Loss: 0.059915 	Validation Loss: 0.389925
# 	Train Accuracy: 97.888d% (39155/40000)	Valdation Accuracy: 90.230d% (9023/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [00:54<00:00,  5.78it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:12<00:00,  6.48it/s]
# 	Training Loss: 0.045682 	Validation Loss: 0.464781
# 	Train Accuracy: 98.410d% (39364/40000)	Valdation Accuracy: 89.960d% (8996/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [00:54<00:00,  5.76it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:12<00:00,  6.49it/s]
# 	Training Loss: 0.053845 	Validation Loss: 0.414648
# 	Train Accuracy: 98.100d% (39240/40000)	Valdation Accuracy: 89.940d% (8994/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:12<00:00,  6.51it/s]
# 	Training Loss: 0.052699 	Validation Loss: 0.403703
# 	Train Accuracy: 98.200d% (39280/40000)	Valdation Accuracy: 90.260d% (9026/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [00:54<00:00,  5.74it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:12<00:00,  6.55it/s]
# 	Training Loss: 0.051591 	Validation Loss: 0.423422
# 	Train Accuracy: 98.195d% (39278/40000)	Valdation Accuracy: 90.190d% (9019/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [00:54<00:00,  5.75it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:12<00:00,  6.49it/s]
# 	Training Loss: 0.045813 	Validation Loss: 0.485847
# 	Train Accuracy: 98.418d% (39367/40000)	Valdation Accuracy: 89.270d% (8927/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [00:54<00:00,  5.77it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:12<00:00,  6.53it/s]
# 	Training Loss: 0.043856 	Validation Loss: 0.416711
# 	Train Accuracy: 98.463d% (39385/40000)	Valdation Accuracy: 90.750d% (9075/10000)
# Student.pt is saved
# Finished Training

# %%
S_loss, S_accuracy = test(Student, test_loader, device=device)
# Out:
# test: 100%|██████████| 79/79 [00:10<00:00,  7.24it/s]
# test_loss: 0.489  test_accuracy: 90.390

# %% [markdown]
# ## Define distillation
#
# ### Define the loss functions

# %%
# Finish the loss function for response-based distillation.
def loss_re(student_logits, teacher_logits, target):
    """
    Response-Based Knowledge Distillation 損失函數
    
    Args:
        student_logits: 學生模型的輸出 logits
        teacher_logits: 教師模型的輸出 logits  
        target: 真實標籤（硬標籤）
    
    Returns:
        loss: 總損失（蒸餾損失 + 硬標籤損失）
    """
    T = 4.0  # Set temperature parameter (溫度參數，用於軟化 softmax 分佈)
    alpha = 0.7  # Set weighting parameter (權重參數，平衡蒸餾損失和硬標籤損失)

    # Implement loss calculation
    
    # 1. 蒸餾損失（Distillation Loss）- 使用 KL 散度衡量學生和教師的軟標籤差異
    # 教師的軟標籤：使用溫度 T 軟化的 softmax
    soft_teacher = F.softmax(teacher_logits / T, dim=1)
    # 學生的軟標籤：使用溫度 T 軟化的 log_softmax（KL散度要求）
    soft_student = F.log_softmax(student_logits / T, dim=1)
    # KL 散度損失，乘以 T^2 來補償溫度縮放對梯度的影響
    distillation_loss = F.kl_div(soft_student, soft_teacher, reduction='batchmean') * (T * T)
    
    # 2. 硬標籤損失（Hard Label Loss）- 使用交叉熵確保學生能正確分類
    student_loss = F.cross_entropy(student_logits, target)
    
    # 3. 總損失：加權組合蒸餾損失和硬標籤損失
    loss = alpha * distillation_loss + (1 - alpha) * student_loss

    return loss

# %%
# Finish the loss function for feature-based distillation.
def loss_fe(student_features, teacher_features, student_logits, target):
    """
    Feature-Based Knowledge Distillation 損失函數
    使用中間層特徵進行知識蒸餾
    
    Args:
        student_features: 學生模型的中間層特徵列表 [feature1, feature2, feature3, feature4]
        teacher_features: 教師模型的中間層特徵列表 [feature1, feature2, feature3, feature4]
        student_logits: 學生模型的輸出 logits
        target: 真實標籤
    
    Returns:
        loss: 總損失（特徵蒸餾損失 + 分類損失）
    """
    # Implement loss calculation whatever you prefer
    
    # 1. 分類損失：確保學生模型能正確分類
    ce_loss = F.cross_entropy(student_logits, target)
    
    # 2. 特徵蒸餾損失：使用 MSE 衡量學生和教師特徵的差異
    feature_loss = 0.0
    
    # 對每一層的特徵計算損失
    for student_feat, teacher_feat in zip(student_features, teacher_features):
        # 因為 ResNet50 和 ResNet18 的特徵通道數不同，我們使用 Spatial Attention
        # 計算每個位置的特徵重要性（沿通道維度求和）
        
        # Student spatial attention: [B, C, H, W] -> [B, 1, H, W]
        student_attention = torch.mean(student_feat, dim=1, keepdim=True)
        student_attention = F.normalize(student_attention.view(student_attention.size(0), -1))
        
        # Teacher spatial attention: [B, C, H, W] -> [B, 1, H, W]  
        teacher_attention = torch.mean(teacher_feat, dim=1, keepdim=True)
        teacher_attention = F.normalize(teacher_attention.view(teacher_attention.size(0), -1))
        
        # 計算注意力圖的 MSE 損失
        feature_loss += F.mse_loss(student_attention, teacher_attention)
    
    # 3. 總損失：分類損失 + 特徵損失
    # 使用權重平衡兩種損失
    beta = 1000.0  # 特徵損失的權重（因為特徵損失通常比較小）
    loss = ce_loss + beta * feature_loss

    return loss

# %% [markdown]
# ### Define Distillation Framework

# %%
class Distiller(nn.Module):
    def __init__(self, teacher, student, type):
        super(Distiller, self).__init__()

        # 1. Finish the __init__ method.
        self.teacher = teacher
        self.student = student
        self.type = type

    def forward(self, x, target):
        # 2. Finish the forward pass.
        
        # 教師模型前向傳播（不計算梯度，只獲取輸出）
        with torch.no_grad():
            teacher_logits, teacher_features = self.teacher(x)
        
        # 學生模型前向傳播（需要計算梯度）
        student_logits, student_features = self.student(x)
        
        # 根據蒸餾類型計算損失
        if self.type == 'response':
            # Response-based: 使用輸出 logits 進行蒸餾
            loss_distill = loss_re(student_logits, teacher_logits, target)
        elif self.type == 'feature':
            # Feature-based: 使用中間層特徵進行蒸餾
            loss_distill = loss_fe(student_features, teacher_features, student_logits, target)
        else:
            raise ValueError(f'Error: only support response-based and feature-based distillation')

        return student_logits, loss_distill

# %% [markdown]
# ### Training function

# %%
def train_distillation(distiller, student, train_loader, val_loader, epochs, learning_rate, device):
    ce_loss = nn.CrossEntropyLoss()
    # define the parameter the optimizer used
    optimizer = torch.optim.Adam(student.parameters(), lr=learning_rate)

    loss = []
    train_error=[]
    val_error = []
    valdation_error = []
    train_loss = []
    valdation_loss = []
    train_accuraacy = []
    valdation_accuracy= []

    for epoch in range(epochs):
        distiller.train()
        distiller.teacher.train()
        distiller.student.train()

        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc  = 0.0
        correct = 0.
        total = 0.
        V_correct = 0.
        V_total = 0.
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            outputs, loss = distiller(images, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            pred = outputs.data.max(1, keepdim=True)[1]
            result = pred.eq(labels.data.view_as(pred))
            result = np.squeeze(result.cpu().numpy())
            correct += np.sum(result)
            total += images.size(0)
            train_bar.desc = "train epoch[{}/{}]".format(epoch + 1, epochs)

        distiller.eval()
        distiller.teacher.eval()
        distiller.student.eval()

        with torch.no_grad():
            val_bar = tqdm(val_loader, file=sys.stdout)
            for val_data in val_bar:

                val_images, val_labels = val_data
                val_images, val_labels = val_images.to(device), val_labels.to(device)

                outputs, loss = distiller(val_images, val_labels)

                valid_loss += loss.item() * val_images.size(0)
                pred = outputs.max(1, keepdim=True)[1]
                V_correct += np.sum(np.squeeze(pred.eq(val_labels.data.view_as(pred))).cpu().numpy())
                V_total += val_images.size(0)
                val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)

        train_loss = train_loss / len(train_loader.dataset)
        train_error.append(train_loss)
        valid_loss = valid_loss / len(val_loader.dataset)
        val_error.append(valid_loss)
        train_accuraacy.append( correct / total)
        valdation_accuracy.append(V_correct / V_total)

        print('\tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(train_loss, valid_loss))
        print('\tTrain Accuracy: %.3fd%% (%2d/%2d)\tValdation Accuracy: %.3fd%% (%2d/%2d) '% (100. * correct / total, correct, total, 100. * V_correct / V_total, V_correct, V_total))

    print('Finished Distilling')

# %% [markdown]
# ## Response-based distillation

# %%
# Decide the epochs and learning rate
Student_re = resnet18(num_classes=10)
Student_re = Student_re.to(device)

# 如果有多個 GPU，使用 DataParallel
if use_multi_gpu:
    Student_re = nn.DataParallel(Student_re)
    print(f'Response-based Student 模型使用 {torch.cuda.device_count()} 個 GPU 進行訓練')

distiller_re = Distiller(Teacher, Student_re, type='response')
train_distillation(distiller_re, Student_re, train_loader, val_loader, epochs=50, learning_rate=0.001, device=device)
# Out:
# Response-based Student 模型使用 2 個 GPU 進行訓練
# train epoch[1/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 11.569585 	Validation Loss: 8.798748
# 	Train Accuracy: 46.445d% (18578/40000)	Valdation Accuracy: 56.750d% (5675/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 7.018527 	Validation Loss: 6.187397
# 	Train Accuracy: 65.438d% (26175/40000)	Valdation Accuracy: 67.800d% (6780/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 5.113157 	Validation Loss: 4.591733
# 	Train Accuracy: 73.780d% (29512/40000)	Valdation Accuracy: 74.360d% (7436/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 3.935260 	Validation Loss: 4.353738
# 	Train Accuracy: 78.668d% (31467/40000)	Valdation Accuracy: 74.300d% (7430/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 3.232839 	Validation Loss: 3.095773
# 	Train Accuracy: 81.912d% (32765/40000)	Valdation Accuracy: 79.650d% (7965/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 2.709283 	Validation Loss: 2.893379
# 	Train Accuracy: 84.330d% (33732/40000)	Valdation Accuracy: 81.860d% (8186/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 2.344933 	Validation Loss: 2.454803
# 	Train Accuracy: 85.858d% (34343/40000)	Valdation Accuracy: 83.750d% (8375/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 2.080581 	Validation Loss: 3.068457
# 	Train Accuracy: 87.300d% (34920/40000)	Valdation Accuracy: 81.130d% (8113/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 1.844556 	Validation Loss: 1.983973
# 	Train Accuracy: 88.457d% (35383/40000)	Valdation Accuracy: 85.470d% (8547/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.655780 	Validation Loss: 1.770908
# 	Train Accuracy: 89.405d% (35762/40000)	Valdation Accuracy: 86.450d% (8645/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.507812 	Validation Loss: 1.721671
# 	Train Accuracy: 90.142d% (36057/40000)	Valdation Accuracy: 87.330d% (8733/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 1.380567 	Validation Loss: 1.599987
# 	Train Accuracy: 91.028d% (36411/40000)	Valdation Accuracy: 87.390d% (8739/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 1.254699 	Validation Loss: 1.420502
# 	Train Accuracy: 91.665d% (36666/40000)	Valdation Accuracy: 88.400d% (8840/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.174603 	Validation Loss: 1.501801
# 	Train Accuracy: 92.185d% (36874/40000)	Valdation Accuracy: 87.840d% (8784/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.102715 	Validation Loss: 1.513855
# 	Train Accuracy: 92.695d% (37078/40000)	Valdation Accuracy: 88.430d% (8843/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.031054 	Validation Loss: 1.369365
# 	Train Accuracy: 93.243d% (37297/40000)	Valdation Accuracy: 88.680d% (8868/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.976194 	Validation Loss: 1.524390
# 	Train Accuracy: 93.487d% (37395/40000)	Valdation Accuracy: 87.690d% (8769/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 0.915716 	Validation Loss: 1.353766
# 	Train Accuracy: 93.968d% (37587/40000)	Valdation Accuracy: 89.020d% (8902/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 0.873129 	Validation Loss: 1.185151
# 	Train Accuracy: 94.177d% (37671/40000)	Valdation Accuracy: 89.370d% (8937/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 0.835896 	Validation Loss: 1.126526
# 	Train Accuracy: 94.570d% (37828/40000)	Valdation Accuracy: 89.720d% (8972/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 0.801501 	Validation Loss: 1.168223
# 	Train Accuracy: 94.752d% (37901/40000)	Valdation Accuracy: 89.680d% (8968/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.762180 	Validation Loss: 1.375967
# 	Train Accuracy: 94.935d% (37974/40000)	Valdation Accuracy: 88.520d% (8852/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.734905 	Validation Loss: 1.091740
# 	Train Accuracy: 95.175d% (38070/40000)	Valdation Accuracy: 90.240d% (9024/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.683960 	Validation Loss: 1.023195
# 	Train Accuracy: 95.707d% (38283/40000)	Valdation Accuracy: 90.340d% (9034/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.663913 	Validation Loss: 1.259751
# 	Train Accuracy: 95.817d% (38327/40000)	Valdation Accuracy: 89.680d% (8968/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.654886 	Validation Loss: 1.026321
# 	Train Accuracy: 95.897d% (38359/40000)	Valdation Accuracy: 90.800d% (9080/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.625950 	Validation Loss: 0.967633
# 	Train Accuracy: 96.105d% (38442/40000)	Valdation Accuracy: 90.510d% (9051/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.602240 	Validation Loss: 0.959008
# 	Train Accuracy: 96.300d% (38520/40000)	Valdation Accuracy: 90.590d% (9059/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.599366 	Validation Loss: 1.018086
# 	Train Accuracy: 96.407d% (38563/40000)	Valdation Accuracy: 90.360d% (9036/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.563692 	Validation Loss: 1.274518
# 	Train Accuracy: 96.505d% (38602/40000)	Valdation Accuracy: 89.600d% (8960/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.553003 	Validation Loss: 0.983997
# 	Train Accuracy: 96.653d% (38661/40000)	Valdation Accuracy: 90.570d% (9057/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.542958 	Validation Loss: 0.876951
# 	Train Accuracy: 96.793d% (38717/40000)	Valdation Accuracy: 90.850d% (9085/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.549648 	Validation Loss: 0.908062
# 	Train Accuracy: 96.765d% (38706/40000)	Valdation Accuracy: 90.550d% (9055/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.524616 	Validation Loss: 0.907440
# 	Train Accuracy: 96.965d% (38786/40000)	Valdation Accuracy: 90.970d% (9097/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.514770 	Validation Loss: 0.876195
# 	Train Accuracy: 96.942d% (38777/40000)	Valdation Accuracy: 91.090d% (9109/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [02:30<00:00,  2.08it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 0.489935 	Validation Loss: 0.860978
# 	Train Accuracy: 97.243d% (38897/40000)	Valdation Accuracy: 90.880d% (9088/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [02:30<00:00,  2.08it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.491749 	Validation Loss: 0.879641
# 	Train Accuracy: 97.105d% (38842/40000)	Valdation Accuracy: 90.410d% (9041/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.474439 	Validation Loss: 0.814694
# 	Train Accuracy: 97.278d% (38911/40000)	Valdation Accuracy: 91.210d% (9121/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.469324 	Validation Loss: 0.920421
# 	Train Accuracy: 97.263d% (38905/40000)	Valdation Accuracy: 90.960d% (9096/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.458821 	Validation Loss: 0.901226
# 	Train Accuracy: 97.330d% (38932/40000)	Valdation Accuracy: 91.060d% (9106/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [02:30<00:00,  2.08it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.445716 	Validation Loss: 0.783863
# 	Train Accuracy: 97.532d% (39013/40000)	Valdation Accuracy: 91.510d% (9151/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.443963 	Validation Loss: 0.784723
# 	Train Accuracy: 97.457d% (38983/40000)	Valdation Accuracy: 91.290d% (9129/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.438236 	Validation Loss: 0.781158
# 	Train Accuracy: 97.498d% (38999/40000)	Valdation Accuracy: 91.580d% (9158/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [02:30<00:00,  2.08it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.425849 	Validation Loss: 0.768627
# 	Train Accuracy: 97.578d% (39031/40000)	Valdation Accuracy: 91.230d% (9123/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.411609 	Validation Loss: 0.772936
# 	Train Accuracy: 97.692d% (39077/40000)	Valdation Accuracy: 91.210d% (9121/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.419662 	Validation Loss: 0.796428
# 	Train Accuracy: 97.657d% (39063/40000)	Valdation Accuracy: 91.290d% (9129/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.418278 	Validation Loss: 0.755188
# 	Train Accuracy: 97.555d% (39022/40000)	Valdation Accuracy: 91.590d% (9159/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [02:30<00:00,  2.08it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 0.395978 	Validation Loss: 0.734155
# 	Train Accuracy: 97.745d% (39098/40000)	Valdation Accuracy: 91.220d% (9122/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [02:30<00:00,  2.09it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.382885 	Validation Loss: 0.759956
# 	Train Accuracy: 97.993d% (39197/40000)	Valdation Accuracy: 91.360d% (9136/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [02:29<00:00,  2.09it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 0.383597 	Validation Loss: 0.759217
# 	Train Accuracy: 97.963d% (39185/40000)	Valdation Accuracy: 91.280d% (9128/10000)
# Finished Distilling

# %%
reS_loss, reS_accuracy = test(distiller_re, test_loader, type='distiller', device=device)
# Out:
# test: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# test_loss: 0.841  test_accuracy: 91.350

# %% [markdown]
# ## Feature-based distillation

# %%
# Decide the epochs and learning rate
Student_fe = resnet18(num_classes=10)
Student_fe = Student_fe.to(device)

# 如果有多個 GPU，使用 DataParallel
if use_multi_gpu:
    Student_fe = nn.DataParallel(Student_fe)
    print(f'Feature-based Student 模型使用 {torch.cuda.device_count()} 個 GPU 進行訓練')

distiller_fe = Distiller(Teacher, Student_fe, type='feature')
train_distillation(distiller_fe, Student_fe, train_loader, val_loader, epochs=50, learning_rate=0.001, device=device)
# Out:
# Feature-based Student 模型使用 2 個 GPU 進行訓練
# train epoch[1/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 10.391021 	Validation Loss: 7.842277
# 	Train Accuracy: 41.355d% (16542/40000)	Valdation Accuracy: 52.250d% (5225/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 6.756028 	Validation Loss: 5.852428
# 	Train Accuracy: 62.983d% (25193/40000)	Valdation Accuracy: 68.350d% (6835/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 5.414731 	Validation Loss: 5.143411
# 	Train Accuracy: 72.513d% (29005/40000)	Valdation Accuracy: 71.160d% (7116/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 4.588222 	Validation Loss: 4.253867
# 	Train Accuracy: 77.787d% (31115/40000)	Valdation Accuracy: 79.210d% (7921/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 4.030825 	Validation Loss: 3.884886
# 	Train Accuracy: 80.983d% (32393/40000)	Valdation Accuracy: 80.780d% (8078/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 3.621822 	Validation Loss: 3.573154
# 	Train Accuracy: 83.698d% (33479/40000)	Valdation Accuracy: 82.820d% (8282/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 3.403619 	Validation Loss: 3.404780
# 	Train Accuracy: 85.180d% (34072/40000)	Valdation Accuracy: 84.640d% (8464/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 3.066043 	Validation Loss: 3.499857
# 	Train Accuracy: 86.922d% (34769/40000)	Valdation Accuracy: 84.320d% (8432/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 2.921339 	Validation Loss: 3.312096
# 	Train Accuracy: 87.775d% (35110/40000)	Valdation Accuracy: 85.780d% (8578/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 2.752225 	Validation Loss: 2.892638
# 	Train Accuracy: 88.767d% (35507/40000)	Valdation Accuracy: 86.930d% (8693/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 2.596736 	Validation Loss: 2.691392
# 	Train Accuracy: 89.748d% (35899/40000)	Valdation Accuracy: 87.220d% (8722/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 2.446047 	Validation Loss: 2.685772
# 	Train Accuracy: 90.478d% (36191/40000)	Valdation Accuracy: 87.420d% (8742/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 2.383611 	Validation Loss: 2.853796
# 	Train Accuracy: 90.847d% (36339/40000)	Valdation Accuracy: 85.920d% (8592/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 2.293518 	Validation Loss: 2.581901
# 	Train Accuracy: 91.438d% (36575/40000)	Valdation Accuracy: 88.120d% (8812/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 2.214561 	Validation Loss: 2.483844
# 	Train Accuracy: 91.970d% (36788/40000)	Valdation Accuracy: 88.510d% (8851/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 2.206375 	Validation Loss: 2.428736
# 	Train Accuracy: 92.160d% (36864/40000)	Valdation Accuracy: 88.830d% (8883/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 2.049073 	Validation Loss: 2.285384
# 	Train Accuracy: 92.945d% (37178/40000)	Valdation Accuracy: 88.910d% (8891/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.998396 	Validation Loss: 2.278192
# 	Train Accuracy: 93.185d% (37274/40000)	Valdation Accuracy: 89.240d% (8924/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.952682 	Validation Loss: 2.361813
# 	Train Accuracy: 93.580d% (37432/40000)	Valdation Accuracy: 89.230d% (8923/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.954775 	Validation Loss: 2.218335
# 	Train Accuracy: 93.715d% (37486/40000)	Valdation Accuracy: 89.680d% (8968/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.864990 	Validation Loss: 2.316358
# 	Train Accuracy: 94.157d% (37663/40000)	Valdation Accuracy: 89.920d% (8992/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.791800 	Validation Loss: 2.053145
# 	Train Accuracy: 94.472d% (37789/40000)	Valdation Accuracy: 90.380d% (9038/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.778079 	Validation Loss: 2.053964
# 	Train Accuracy: 94.662d% (37865/40000)	Valdation Accuracy: 90.190d% (9019/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.728759 	Validation Loss: 2.191283
# 	Train Accuracy: 95.052d% (38021/40000)	Valdation Accuracy: 90.010d% (9001/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.714239 	Validation Loss: 2.020483
# 	Train Accuracy: 95.358d% (38143/40000)	Valdation Accuracy: 90.500d% (9050/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.667245 	Validation Loss: 2.091472
# 	Train Accuracy: 95.475d% (38190/40000)	Valdation Accuracy: 89.320d% (8932/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [02:31<00:00,  2.06it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.616908 	Validation Loss: 1.970618
# 	Train Accuracy: 95.655d% (38262/40000)	Valdation Accuracy: 90.610d% (9061/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.592972 	Validation Loss: 2.106804
# 	Train Accuracy: 95.757d% (38303/40000)	Valdation Accuracy: 89.830d% (8983/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.563737 	Validation Loss: 2.242685
# 	Train Accuracy: 95.900d% (38360/40000)	Valdation Accuracy: 89.830d% (8983/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.554645 	Validation Loss: 1.936942
# 	Train Accuracy: 96.282d% (38513/40000)	Valdation Accuracy: 90.560d% (9056/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 1.526844 	Validation Loss: 2.051109
# 	Train Accuracy: 96.240d% (38496/40000)	Valdation Accuracy: 90.070d% (9007/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.461967 	Validation Loss: 1.920301
# 	Train Accuracy: 96.472d% (38589/40000)	Valdation Accuracy: 90.940d% (9094/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.494794 	Validation Loss: 2.077966
# 	Train Accuracy: 96.537d% (38615/40000)	Valdation Accuracy: 90.570d% (9057/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.440750 	Validation Loss: 1.956642
# 	Train Accuracy: 96.748d% (38699/40000)	Valdation Accuracy: 90.910d% (9091/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.469297 	Validation Loss: 1.951522
# 	Train Accuracy: 96.802d% (38721/40000)	Valdation Accuracy: 90.840d% (9084/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.482389 	Validation Loss: 1.944356
# 	Train Accuracy: 96.968d% (38787/40000)	Valdation Accuracy: 90.490d% (9049/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 1.406585 	Validation Loss: 1.789150
# 	Train Accuracy: 97.188d% (38875/40000)	Valdation Accuracy: 91.170d% (9117/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.379320 	Validation Loss: 1.955365
# 	Train Accuracy: 97.248d% (38899/40000)	Valdation Accuracy: 90.970d% (9097/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.355811 	Validation Loss: 1.901463
# 	Train Accuracy: 97.248d% (38899/40000)	Valdation Accuracy: 91.330d% (9133/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.349091 	Validation Loss: 1.847520
# 	Train Accuracy: 97.468d% (38987/40000)	Valdation Accuracy: 90.580d% (9058/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.375795 	Validation Loss: 1.884013
# 	Train Accuracy: 97.365d% (38946/40000)	Valdation Accuracy: 90.910d% (9091/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.324583 	Validation Loss: 1.758751
# 	Train Accuracy: 97.703d% (39081/40000)	Valdation Accuracy: 91.210d% (9121/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [02:31<00:00,  2.06it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:36<00:00,  2.16it/s]
# 	Training Loss: 1.284171 	Validation Loss: 1.877796
# 	Train Accuracy: 97.963d% (39185/40000)	Valdation Accuracy: 90.990d% (9099/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [02:31<00:00,  2.07it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:37<00:00,  2.12it/s]
# 	Training Loss: 1.323432 	Validation Loss: 1.893991
# 	Train Accuracy: 97.655d% (39062/40000)	Valdation Accuracy: 90.960d% (9096/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [02:36<00:00,  2.00it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# 	Training Loss: 1.283814 	Validation Loss: 1.894419
# 	Train Accuracy: 97.865d% (39146/40000)	Valdation Accuracy: 91.630d% (9163/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [02:36<00:00,  2.00it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.284766 	Validation Loss: 1.897950
# 	Train Accuracy: 97.935d% (39174/40000)	Valdation Accuracy: 90.770d% (9077/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [02:37<00:00,  1.99it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.281484 	Validation Loss: 1.757685
# 	Train Accuracy: 98.070d% (39228/40000)	Valdation Accuracy: 91.080d% (9108/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [02:36<00:00,  2.00it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 1.254379 	Validation Loss: 1.824310
# 	Train Accuracy: 98.045d% (39218/40000)	Valdation Accuracy: 90.420d% (9042/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [02:36<00:00,  2.00it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:36<00:00,  2.14it/s]
# 	Training Loss: 1.209214 	Validation Loss: 1.741596
# 	Train Accuracy: 98.130d% (39252/40000)	Valdation Accuracy: 91.270d% (9127/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [02:37<00:00,  1.99it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:37<00:00,  2.13it/s]
# 	Training Loss: 1.232892 	Validation Loss: 1.777612
# 	Train Accuracy: 98.263d% (39305/40000)	Valdation Accuracy: 91.220d% (9122/10000)
# Finished Distilling

# %%
ftS_loss, ftS_accuracy = test(distiller_fe, test_loader, type='distiller', device=device)
# Out:
# test: 100%|██████████| 79/79 [00:36<00:00,  2.15it/s]
# test_loss: 1.820  test_accuracy: 91.510

# %% [markdown]
# ## Result and Comparison

# %%
print(f'Teacher from scratch: loss = {T_loss:.2f}, accuracy = {T_accuracy:.2f}')
print(f'Student from scratch: loss = {S_loss:.2f}, accuracy = {S_accuracy:.2f}')
print(f'Response-based student: loss = {reS_loss:.2f}, accuracy = {reS_accuracy:.2f}')
print(f'Featured-based student: loss = {ftS_loss:.2f}, accuracy = {ftS_accuracy:.2f}')
# Out:
# Teacher from scratch: loss = 0.43, accuracy = 90.90
# Student from scratch: loss = 0.49, accuracy = 90.39
# Response-based student: loss = 0.84, accuracy = 91.35
# Featured-based student: loss = 1.82, accuracy = 91.51
